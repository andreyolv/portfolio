# %%
# pip install quandl
import quandl

# %%
quandl.ApiConfig.api_key = 'd7_z6Wcz18pj5sgXiQHP'

# %%
df_selic = quandl.get('BCB/432', start_date='2000-01-01')
df_selic.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_selic
# Out:
#             Value
# Date
# 2000-01-01  19.00
# 2000-01-02  19.00
# 2000-01-03  19.00
# 2000-01-04  19.00
# 2000-01-05  19.00
# ...           ...
# 2021-07-07   4.25
# 2021-07-08   4.25
# 2021-07-09   4.25
# 2021-07-10   4.25
# 2021-07-11   4.25
#
# [7863 rows x 1 columns]

# %%
df_ipca = quandl.get('BCB/13522', start_date='2000-01-01')
df_ipca.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_ipca
# Out:
#             Value
# Date
# 2000-01-31   8.85
# 2000-02-29   7.86
# 2000-03-31   6.92
# 2000-04-30   6.77
# 2000-05-31   6.47
# ...           ...
# 2021-02-28   5.20
# 2021-03-31   6.10
# 2021-04-30   6.76
# 2021-05-31   8.06
# 2021-06-30   8.35
#
# [258 rows x 1 columns]

# %%
df_pib = quandl.get('ODA/BRA_NGDPD', start_date='2000-01-01')
df_pib.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_pib
# Out:
#                Value
# Date
# 2000-12-31   655.435
# 2001-12-31   559.962
# 2002-12-31   509.358
# 2003-12-31   557.681
# 2004-12-31   668.432
# 2005-12-31   890.671
# 2006-12-31  1106.370
# 2007-12-31  1396.110
# 2008-12-31  1694.870
# 2009-12-31  1667.680
# 2010-12-31  2207.620
# 2011-12-31  2613.990
# 2012-12-31  2464.400
# 2013-12-31  2471.560
# 2014-12-31  2456.170
# 2015-12-31  1800.030
# 2016-12-31  1795.600
# 2017-12-31  2053.210
# 2018-12-31  1868.180
# 2019-12-31  1960.190
# 2020-12-31  2062.500
# 2021-12-31  2156.500
# 2022-12-31  2255.580
# 2023-12-31  2359.530
# 2024-12-31  2468.220
